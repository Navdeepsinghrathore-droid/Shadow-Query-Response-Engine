# %%
# Shadow Query Response Engine - Google Colab Compatible

# ===== GREETING DICTIONARY =====
greetings = {
    1: "Salute, Shadow Cadet.",
    2: "Bonjour, Sentinel.",
    3: "Eyes open, Phantom.",
    4: "In the wind, Commander.",
    5: "The unseen hand moves, Whisper."
}

# ===== SPECIAL PHRASES DICTIONARY =====
special_phrases = {
    "Omega Echo": "The shadow moves, but the light never follows.",
    "The bridge is burning": "What was built must sometimes fall. What rises next is the real question.",
    "The fire rises": "The fire rises, the bridge burns.",
    "Candle Shop": "It was always there, wasn’t it?",
    "Where does the river start?": "The map is not the territory, and the water remembers everything.",
    "Ghost Key 27": "It was never yours to find, and yet here we are.",
    "The Red Hour": "The clock does not move, yet the time changes.",
    "Eclipse Protocol": "Even in darkness, some things are never hidden."
}

# ===== RULE ENGINE (SIMPLIFIED SAMPLE RULES) =====
def get_response(agent_level, query):
    for phrase in special_phrases:
        if phrase.lower() in query.lower():
            return special_phrases[phrase]

    if agent_level == 1:
        if "extraction" in query.lower():
            return "Step 1: Deploy smoke. Step 2: Use route Omega-17. Step 3: Contact handler via burst signal."
        elif "disguise" in query.lower():
            return "Use layer-based concealment: facial, behavioral, and digital masking."
        elif "tracking chip" in query.lower():
            return "Think of it like pulling a weed—grasp at the base and twist till it snaps."
    elif agent_level == 2:
        if "false identity" in query.lower():
            return "Checklist: forged ID, consistent backstory, behavioral sync, and no digital footprint."
        elif "safehouse" in query.lower():
            return "Location scrambled. Access K-41 via biometric + cipher at Gopi's Stall. Cipher format: ###-//-@@"
    elif agent_level == 3:
        if "compromised asset" in query.lower():
            return "Option 1: Extraction. Option 2: Misdirection. Option 3: Containment. Risk analysis required."
        elif "thermal surveillance" in query.lower():
            return "Use foil-lined innerwear, cover with organic overlays. High foliage zones give best cover."
        elif "financial forensics" in query.lower():
            return "Watch for shell transfers, micro-spending bursts, and ghost wallet patterns."
    elif agent_level == 4:
        if "abort mission" in query.lower():
            return "Wind echoes. Switch to Black Echo. Rendezvous at point delta."
        elif "fail-safe" in query.lower():
            return "Like Operation Icefall—always leave a shadow trail to loop back."
    elif agent_level == 5:
        if "project eclipse" in query.lower():
            return "Once, in the age of ashes, all records were swept by the Omega Wave."
        elif "misinformation campaigns" in query.lower():
            return "Recall the Cold Whisper program—fiction bent truth better than fact."

    return "Query classified or unknown. Please rephrase or escalate."

# ===== RUN INTERACTIVE BLOCK =====
def run_shadow_engine(agent_level, query):
    print("\n==============================")
    print("   RAW Query Response Engine")
    print("==============================\n")
    if agent_level not in range(1, 6):
        print("Invalid agent level. Must be between 1 and 5.")
        return
    print("--- RESPONSE ---")
    print(f"Greeting: {greetings[agent_level]}")
    response = get_response(agent_level, query)
    print(f"Response: {response}")
    print("--- END ---\n")

# Example usage
# Modify these values to test other cases
agent_level = 4
query = "how i abort mission"
run_shadow_engine(agent_level, query)
